# %% [markdown]
# # MiniViT: Efficient Vision Transformer for Edge Devices
#
# Train a 2M-param ViT on a laptop CPU in 30 minutes.

# %% [markdown]
# ## 1. Install

# %% [markdown]
# ## 2. Load Model

# %% [markdown]
# ## 3. Run Inference

# %% [markdown]
# ## 4. Show Results
